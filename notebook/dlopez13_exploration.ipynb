# %% [markdown]
# ### Data Exploration -- Sign lenguage

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Test Data

# %%
# test data
address = '/home/dlopez/code/mtaha5/sign-language/raw_data/sign_mnist_test.csv'

# read CSV - DataFrame
df_test = pd.read_csv(address)

# %%
df_test.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      6     149     149     150     150     150     151     151     150
# 1      5     126     128     131     132     133     134     135     135
# 2     10      85      88      92      96     105     123     135     143
# 3      0     203     205     207     206     207     209     210     209
# 4      3     188     191     193     195     199     201     202     203
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     151  ...       138       148       127        89        82        96
# 1     136  ...        47       104       194       183       186       184
# 2     147  ...        68       166       242       227       230       227
# 3     210  ...       154       248       247       248       253       236
# 4     203  ...        26        40        64        48        29        46
#
#    pixel781  pixel782  pixel783  pixel784
# ...

# %%
#image size 28 x28
#28x28=784 columns

# %%
df_test.shape
# Out:
# (7172, 785)

# %%
# Number of label
df_test['label'].nunique()
# Out:
# 24

# %%
# Compute the number of duplicated rows
df_test.duplicated().sum()
# Out:
# 0

# %%
# Counting the number of NaN for each column
df_test.isnull().sum().sort_values(ascending=False)
# Out:
# label       0
# pixel516    0
# pixel518    0
# pixel519    0
# pixel520    0
#            ..
# pixel264    0
# pixel265    0
# pixel266    0
# pixel267    0
# pixel784    0
# Length: 785, dtype: int64

# %%
df_test.dtypes
# Out:
# label       int64
# pixel1      int64
# pixel2      int64
# pixel3      int64
# pixel4      int64
#             ...
# pixel780    int64
# pixel781    int64
# pixel782    int64
# pixel783    int64
# pixel784    int64
# Length: 785, dtype: object

# %%
images = df_test.iloc[:, 1:].values  
labels = df_test['label'].values

# %%
num_images= 35
num_columns = 5  
num_rows = num_images // num_columns  

plt.figure(figsize=(15, 12))

for i in range(num_images):
    plt.subplot(num_rows, num_columns, i+1)
    img = images[i].reshape(28, 28)  # Size image 28x28
    plt.imshow(img, cmap='gray')
    plt.title(f"Label: {labels[i]}", fontsize=10)
    plt.axis('off')

# %%
#image label 0
label_0_data = df_test[df_test['label'] == 0]

num_images_to_display = 15

num_columns_0 = 5  
num_rows_0 = num_images_to_display // num_columns_0

label_0_images = label_0_data.iloc[:num_images_to_display, 1:].values

plt.figure(figsize=(15, 10))

for i in range(num_images_to_display):
    plt.subplot(num_rows_0, num_columns_0, i+1)
    img = label_0_images[i].reshape(28, 28)  # image size 28x28
    plt.imshow(img, cmap='gray')
    plt.title(f"Label: 0")
    plt.axis('off')

# %%
df_test['label'].value_counts()
# Out:
# 4     498
# 7     436
# 1     432
# 12    394
# 6     348
# 15    347
# 21    346
# 24    332
# 0     331
# 10    331
# 2     310
# 13    291
# 8     288
# 23    267
# 20    266
# 19    248
# 5     247
# 14    246
# 18    246
# 3     245
# 11    209
# 22    206
# 16    164
# 17    144
# Name: label, dtype: int64

# %% [markdown]
# #### Train data

# %%
# test data
address = '/home/dlopez/code/mtaha5/sign-language/raw_data/sign_mnist_train.csv'

# CSV into DataFrame
df_train = pd.read_csv(address)

# %%
df_train.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     153  ...       207       207       207       207       206       206
# 1     158  ...        69       149       128        87        94       163
# 2     187  ...       202       201       200       199       198       199
# 3     210  ...       235       234       233       231       230       226
# 4     185  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# ...

# %%
df_train['label'].value_counts()
# Out:
# 17    1294
# 16    1279
# 11    1241
# 22    1225
# 5     1204
# 18    1199
# 3     1196
# 14    1196
# 19    1186
# 23    1164
# 8     1162
# 20    1161
# 13    1151
# 2     1144
# 0     1126
# 24    1118
# 10    1114
# 6     1090
# 15    1088
# 21    1082
# 12    1055
# 7     1013
# 1     1010
# 4      957
# Name: label, dtype: int64

# %%
df_train.shape
# Out:
# (27455, 785)
