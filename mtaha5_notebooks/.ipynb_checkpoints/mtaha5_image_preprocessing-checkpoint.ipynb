# %% [markdown]
# # Image Preprocessing

# %% [markdown]
# ## Transfer image to Black-White

# %%
import glob
from PIL import Image 
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.image import rgb_to_grayscale
# Out:
# 2023-11-28 23:05:46.762852: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-28 23:05:46.807584: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-28 23:05:46.809353: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-28 23:05:47.845237: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
! pwd
# Out:
# /home/mtaha5/code/mtaha5/sign-language/notebooks

# %%
images = []
for f in glob.iglob("../raw_data/camera/*"):
    if f.endswith('.jpg'):
        images.append(np.asarray(Image.open(f)))

images = np.array(images)

# %%
images.shape
# Out:
# (13, 1080, 1920, 3)

# %%
img = images[:1]
plt.imshow(np.squeeze(img))

# %%
from tensorflow.image import rgb_to_grayscale
images_bw = rgb_to_grayscale(images)

# %%
images_bw.shape
# Out:
# TensorShape([13, 1080, 1920, 1])

# %%
img = images_bw[:1]
plt.imshow(np.squeeze(img), cmap='gray')

# %% [markdown]
# ## Hand Segmentation

# %%
# !pwd
# Out:
# /home/mtaha5/code/mtaha5/sign-language/notebooks

# %%
image_test = np.load('image_test.npy')
image_test.shape
# Out:
# (161, 151, 3)

# %%
img_gray = rgb_to_grayscale(image_test)
img_gray.shape
# Out:
# TensorShape([161, 151, 1])

# %%
plt.imshow(img_gray, cmap='gray')

# %%
from tensorflow import image
img = image.resize(img_gray, (48, 48))

# %%
img.shape
# Out:
# TensorShape([48, 48, 1])

# %%
plt.imshow(img, cmap='gray')

# %%
h, w , c = 394, 704 , 3

# %%
x_min = 274

x_max = 422

y_min = 61

y_max = 320

extra = 30

# %%
if x_max+extra > w:
    x_max_new = w
else:
    x_max_new = x_max+extra
if x_min-extra < 0:
    x_min_new = 0
else:
    x_min_new = x_min-extra
if y_max+extra > h:
    y_max_new = h
else:
    y_max_new = y_max+extra
if y_min-extra < 0:
    y_min_new = 0
else:
    y_min_new = y_min-extra

# %%
y_max_new - y_min_new
# Out:
# 319

# %%
x_max_new - x_min_new
# Out:
# 208

# %%
max(y_max_new - y_min_new, x_max_new - x_min_new)
# Out:
# 319

# %%
image_test.shape
# Out:
# (319, 208, 3)

# %%
img_crop = image_test[y_min-extra:y_max+extra, x_min-extra:x_max+extra]
img_crop.shape
# Out:
# (375, 288, 3)

# %%
plt.imshow(img_crop)
